# %%
#import matplotlib
#matplotlib.use("Agg")  # Must be at the top before importing pyplot

# %run ./"0 Imports and functions.ipynb"

# Load cube information 

#File_Descriptor='cmz_CO_J3_2_'
File_Descriptor='cmz_CO_J1_0_'
#File_Descriptor='cmz_CO_J1_0_COMPLETE'


##################################

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'rb') as file:
    
    Cube_Information = pickle.load(file)
    
with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'rb') as file:
    
    Pointing_Information = pickle.load(file)
    
print(Cube_Information)

Cube_Information["Beam_Position_angle"]=0*u.deg
#Cube_Information["File_Name"] = "Cropped_4.3pc_beam_NGC_253_HCN_J1-0_71.0x360.0pc_reprojecte_3.4_vel_res_.fits"
#%matplotlib widget 
#%matplotlib notebook
#%matplotlib agg
#%pip install --upgrade pyqt5

#%matplotlib qt
# Out:
# /home/ben/miniconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# astropy 5.1.dev153+gb740594dc
# spectral_cube 0.6.1.dev22+g003ef16
# spectral_cube file path /home/ben/.local/lib/python3.8/site-packages/spectral_cube/__init__.py
# reproject 0.8
# 3.3.4 Matplotlib
# /home/ben/miniconda3/lib/python3.8/site-packages/matplotlib/__init__.py
# 1.23.1 Numpy
# astrodendro_file: /home/ben/.local/lib/python3.8/site-packages/astrodendro/__init__.py
# Results will be saved to Directory ./Result Files
# Cubes will be saved and loaded with Directory ./Spectral Cubes
# Plots will be saved to Directory ./Plots
# Dendrograms will be saved to Directory ./Dendrograms
# {'Original_File_Name': 'tttttttttttt.fits', 'File_Descriptor': 'cmz_CO_J1_0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (180., -0.)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.15271202e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 0.125 deg>, 'original_BMIN': <Quantity 0.125 deg>, 'original_BMAJ_pc': <Quantity 1.78416283e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 1.78416283e-05 Mpc rad>, 'desired_beam_size': <Quantity 26.5 pc>, 'original_pixel_scale_x': <Quantity 450. arcsec / pix>, 'original_pixel_scale_y': <Quantity 450. arcsec / pix>, 'original_spatial_scale_x': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 0.00027778 deg pix / arcsec>, 'original_beam_oversampling_MIN': <Quantity 0.00027778 deg pix / arcsec>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_26.5pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 133.67614002 arcsec / pix>, 'arc_per_pix_x': <Quantity 133.67614002 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 668.38070012 arcsec>, 'beam_minor': <Quantity 668.38070012 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 5.3e-06 Mpc / pix>, 'spatial_scale_y': <Quantity 5.3e-06 Mpc / pix>, 'spatial_scale': <Quantity 133.67614002 arcsec>, 'velocity_scale': <Quantity 5.00838299 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON'  'GLAT'  'VRAD-W2F'
# CRVAL : 200.0  -5.2  -251210.32480923
# CRPIX : 0.0  0.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.037132261117552  0.037132261117552  5008.3829852496
# NAXIS : 0  0}

# %% [markdown]
# # 2a Dendogram calculation

# %%
# Calculate the dendrogram and save it 
# At the noisiest part of the cube in channel 0, I found .15K noise (in carta)
#Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5,manual_noise=.115*u.K)
Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5,
                       
                       image_args={"FIX_AXIS":True,
                                   "FIGSIZE": (50,5),
                                   "COLORBARSCALE":.15,
                                   "SCALE":1,
                                   "XLABELS_NUM":58,
                                   "VMAX":550,
                                   "VMIN":-100,
                                   "SHOW":True,
                                   "DPI":800
                                  }
                      
                      )
# Out:
# The continuum has unit
# The continuum is unitless; unit defaults to Jy/beam
# 0.04543654078844492 K   RMS Noise for cmz_CO_J1_0_
# (50, 5)
# changing xlables: [199.96286774 199.29448704 198.62610634 197.95772564 197.28934494
#  196.62096424 195.95258354 195.28420284 194.61582214 193.94744144
#  193.27906074 192.61068004 191.94229934 191.27391864 190.60553794
#  189.93715724 189.26877654 188.60039584 187.93201514 187.26363444
#  186.59525374 185.92687304 185.25849234 184.59011164 183.92173094
#  183.25335024 182.58496954 181.91658884 181.24820814 180.57982744
#  179.91144674 179.24306604 178.57468534 177.90630464 177.23792393
#  176.56954323 175.90116253 175.23278183 174.56440113 173.89602043
#  173.22763973 172.55925903 171.89087833 171.22249763 170.55411693
#  169.88573623 169.21735553 168.54897483 167.88059413 167.21221343
#  166.54383273 165.87545203 165.20707133 164.53869063 163.87030993
#  163.20192923 162.53354853 161.86516783 161.19678713 160.52840643]
# to: [-20.  -19.3 -18.6 -18.  -17.3 -16.6 -16.  -15.3 -14.6 -13.9 -13.3 -12.6
#  -11.9 -11.3 -10.6  -9.9  -9.3  -8.6  -7.9  -7.3  -6.6  -5.9  -5.3  -4.6
#   -3.9  -3.3  -2.6  -1.9  -1.2  -0.6   0.1   0.8   1.4   2.1   2.8   3.4
#    4.1   4.8   5.4   6.1   6.8   7.4   8.1   8.8   9.4  10.1  10.8  11.5
#   12.1  12.8  13.5  14.1  14.8  15.5  16.1  16.8  17.5  18.1  18.8  19.5]
# (50, 5)
# changing xlables: [   0   95  190  286  381  477  572  667  763  858  954 1049 1144 1240
#  1335 1431 1526 1621 1717 1812 1908 2003 2098 2194 2289 2385 2480 2575
#  2671 2766 2862 2957 3052 3148 3243 3339 3434 3529 3625 3720 3816 3911
#  4006 4102 4197 4293 4388 4483 4579 4674 4770 4865 4960 5056 5151 5247
#  5342 5437 5533 5628]
# [ 2814  1814   814  -185 -1185 -2185] [   0.   215.4  430.8  646.2  861.6 1077. ]
# to: [ 2814  1814   814  -185 -1185 -2185]
# (50, 5)
# changing xlables: [   0   95  190  286  381  477  572  667  763  858  954 1049 1144 1240
#  1335 1431 1526 1621 1717 1812 1908 2003 2098 2194 2289 2385 2480 2575
#  2671 2766 2862 2957 3052 3148 3243 3339 3434 3529 3625 3720 3816 3911
#  4006 4102 4197 4293 4388 4483 4579 4674 4770 4865 4960 5056 5151 5247
#  5342 5437 5533 5628]
# [ 2814  1814   814  -185 -1185 -2185] [   0.   215.4  430.8  646.2  861.6 1077. ]
# to: [ 2814  1814   814  -185 -1185 -2185]
# (13.33, 8)
# (13.33, 8)
# Computing Dendrogram...
# Dendrogram for cmz_CO_J1_0_ saved to Dendrograms/Cropped_26.5pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram.fits

# %% [markdown]
# # x. save cube information

# %%
# Re-save the cube information, now including the dendrogram file name and the reprojected continuum

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'wb') as file:
    pickle.dump(Cube_Information, file)

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'wb') as file:
    pickle.dump(Pointing_Information, file)

print(Cube_Information)
# Out:
# {'Original_File_Name': 'tttttttttttt.fits', 'File_Descriptor': 'cmz_CO_J1_0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (180., -0.)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.15271202e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 0.125 deg>, 'original_BMIN': <Quantity 0.125 deg>, 'original_BMAJ_pc': <Quantity 1.78416283e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 1.78416283e-05 Mpc rad>, 'desired_beam_size': <Quantity 26.5 pc>, 'original_pixel_scale_x': <Quantity 450. arcsec / pix>, 'original_pixel_scale_y': <Quantity 450. arcsec / pix>, 'original_spatial_scale_x': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 0.00027778 deg pix / arcsec>, 'original_beam_oversampling_MIN': <Quantity 0.00027778 deg pix / arcsec>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_26.5pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 133.67614002 arcsec / pix>, 'arc_per_pix_x': <Quantity 133.67614002 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 668.38070012 arcsec>, 'beam_minor': <Quantity 668.38070012 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 5.3e-06 Mpc / pix>, 'spatial_scale_y': <Quantity 5.3e-06 Mpc / pix>, 'spatial_scale': <Quantity 133.67614002 arcsec>, 'velocity_scale': <Quantity 5.00838299 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON'  'GLAT'  'VRAD-W2F'
# CRVAL : 200.0  -5.2  -251210.32480923
# CRPIX : 0.0  0.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.037132261117552  0.037132261117552  5008.3829852496
# NAXIS : 0  0, 'Corresponding_Continuum_Reprojected': 'gc_850micron_dust_Reproject_to_cmz_CO_J1_0_.fits', 'RMS_Noise': <Quantity 0.04543654 K>, 'Corresponding_Dendrogram': 'Cropped_26.5pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram'}

# %%
# Out:
# 4.3 pc
# 5.999999999999992e-07 MPC per pix
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# 0.2134332005353266 Unmatched Noise (K) Abs =  All
# 0.2134332005353266 Matched Noise (K) Abs =  All
# 0.010994999132779756
# 7.39599999999976e-13 <class 'float'>
# 0.253411047675004 arcsec 0.253411047675004 arcsec
# 28.327250000000895 pix2
# 5 5 2 0
# 5 5 2 0 2 2
# HCN J1-0_Abs_New_Cropped_4.3pc_beam__NGC_HCN_J1_0_70x360pc_3.3_vel_res_0.16666666666666666_beam_size_req_1_times_beam_pixels_1.0_delt_factor_5.0_SNR.fits
# done
