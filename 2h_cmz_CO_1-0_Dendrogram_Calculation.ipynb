# %%
#import matplotlib
#matplotlib.use("Agg")  # Must be at the top before importing pyplot

# %run ./"0 Imports and functions.ipynb"

# Load cube information 

#File_Descriptor='cmz_CO_J3_2_'
File_Descriptor='cmz_CO_J1_0_'
#File_Descriptor='cmz_CO_J1_0_COMPLETE'


##################################

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'rb') as file:
    
    Cube_Information = pickle.load(file)
    
with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'rb') as file:
    
    Pointing_Information = pickle.load(file)
    
print(Cube_Information)

Cube_Information["Beam_Position_angle"]=0*u.deg
#Cube_Information["File_Name"] = "Cropped_4.3pc_beam_NGC_253_HCN_J1-0_71.0x360.0pc_reprojecte_3.4_vel_res_.fits"
#%matplotlib widget 
#%matplotlib notebook
#%matplotlib agg
#%pip install --upgrade pyqt5

#%matplotlib qt
# Out:
# /home/ben/miniconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# astropy 5.1.dev153+gb740594dc
# spectral_cube 0.6.1.dev22+g003ef16
# spectral_cube file path /home/ben/.local/lib/python3.8/site-packages/spectral_cube/__init__.py
# reproject 0.8
# 1.23.1 Numpy
# astrodendro_file: /home/ben/.local/lib/python3.8/site-packages/astrodendro/__init__.py
# Results will be saved to Directory ./Result Files
# Cubes will be saved and loaded with Directory ./Spectral Cubes
# Plots will be saved to Directory ./Plots
# Dendrograms will be saved to Directory ./Dendrograms
# {'Original_File_Name': 'tttttttttttt.fits', 'File_Descriptor': 'cmz_CO_J1_0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (180., -0.)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.15271202e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 0.125 deg>, 'original_BMIN': <Quantity 0.125 deg>, 'original_BMAJ_pc': <Quantity 1.78416283e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 1.78416283e-05 Mpc rad>, 'desired_beam_size': <Quantity 73. pc>, 'original_pixel_scale_x': <Quantity 450. arcsec / pix>, 'original_pixel_scale_y': <Quantity 450. arcsec / pix>, 'original_spatial_scale_x': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 0.00027778 deg pix / arcsec>, 'original_beam_oversampling_MIN': <Quantity 0.00027778 deg pix / arcsec>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_73.0pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 368.23993289 arcsec / pix>, 'arc_per_pix_x': <Quantity 368.23993289 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 1841.19966447 arcsec>, 'beam_minor': <Quantity 1841.19966447 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale_y': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale': <Quantity 368.23993289 arcsec>, 'velocity_scale': <Quantity 5.00838299 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON'  'GLAT'  'VRAD-W2F'
# CRVAL : 200.0  -5.2  -251210.32480923
# CRPIX : 0.0  0.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.10228887024835  0.10228887024835  5008.3829852496
# NAXIS : 0  0, 'Corresponding_Continuum_Reprojected': 'gc_850micron_dust_Reproject_to_cmz_CO_J1_0_.fits', 'RMS_Noise': <Quantity 0.03010535 K>, 'Corresponding_Dendrogram': 'Cropped_73.0pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram'}
# Requirement already satisfied: pyqt5 in /home/ben/miniconda3/lib/python3.8/site-packages (5.15.11)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /home/ben/miniconda3/lib/python3.8/site-packages (from pyqt5) (5.15.16)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /home/ben/miniconda3/lib/python3.8/site-packages (from pyqt5) (12.15.0)
# WARNING: You are using pip version 21.0.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/home/ben/miniconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2a Dendogram calculation

# %%
# Calculate the dendrogram and save it 
# At the noisiest part of the cube in channel 0, I found .15K noise (in carta)
#Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5,manual_noise=.115*u.K)
Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5,
                       
                       image_args={"FIX_AXIS":True,
                                   "FIGSIZE": (50,5),
                                   "COLORBARSCALE":.15,
                                   "SCALE":1,
                                   "XLABELS_NUM":58,
                                   "VMAX":550,
                                   "VMIN":-100,
                                   "SHOW":True,
                                   "DPI":800
                                  }
                      
                      )
# Out:
# The continuum has unit
# The continuum is unitless; unit defaults to Jy/beam
# 0.030105349290090695 K   RMS Noise for cmz_CO_J1_0_
# (50, 5)
# changing xlables: [199.89771113 199.28397791 198.67024469 198.05651147 197.44277824
#  196.82904502 196.2153118  195.60157858 194.98784536 194.37411214
#  193.76037891 193.14664569 192.53291247 191.91917925 191.30544603
#  190.69171281 190.07797959 189.46424636 188.85051314 188.23677992
#  187.6230467  187.00931348 186.39558026 185.78184704 185.16811381
#  184.55438059 183.94064737 183.32691415 182.71318093 182.09944771
#  181.48571449 180.87198126 180.25824804 179.64451482 179.0307816
#  178.41704838 177.80331516 177.18958193 176.57584871 175.96211549
#  175.34838227 174.73464905 174.12091583 173.50718261 172.89344938
#  172.27971616 171.66598294 171.05224972 170.4385165  169.82478328
#  169.21105006 168.59731683 167.98358361 167.36985039 166.75611717
#  166.14238395 165.52865073 164.9149175  164.30118428 163.68745106
#  163.07371784 162.45998462 161.8462514  161.23251818 160.61878495
#  160.00505173]
# to: [-19.9 -19.3 -18.7 -18.1 -17.4 -16.8 -16.2 -15.6 -15.  -14.4 -13.8 -13.1
#  -12.5 -11.9 -11.3 -10.7 -10.1  -9.5  -8.9  -8.2  -7.6  -7.   -6.4  -5.8
#   -5.2  -4.6  -3.9  -3.3  -2.7  -2.1  -1.5  -0.9  -0.3   0.4   1.    1.6
#    2.2   2.8   3.4   4.    4.7   5.3   5.9   6.5   7.1   7.7   8.3   8.9
#    9.6  10.2  10.8  11.4  12.   12.6  13.2  13.9  14.5  15.1  15.7  16.3
#   16.9  17.5  18.2  18.8  19.4  20. ]
# (50, 5)
# changing xlables: [   0   87  175  262  350  438  525  613  700  788  876  963 1051 1138
#  1226 1314 1401 1489 1576 1664 1752 1839 1927 2014 2102 2190 2277 2365
#  2452 2540 2628 2715 2803 2890 2978 3066 3153 3241 3328 3416 3504 3591
#  3679 3766 3854 3942 4029 4117 4204 4292 4380 4467 4555 4642 4730 4818
#  4905 4993 5080 5168 5256 5343 5431 5518 5606 5694]
# [ 2847  1847   847  -152 -1152 -2152] [  0.   78.2 156.4 234.6 312.8 391. ]
# to: [ 2847  1847   847  -152 -1152 -2152]
# (50, 5)
# changing xlables: [   0   87  175  262  350  438  525  613  700  788  876  963 1051 1138
#  1226 1314 1401 1489 1576 1664 1752 1839 1927 2014 2102 2190 2277 2365
#  2452 2540 2628 2715 2803 2890 2978 3066 3153 3241 3328 3416 3504 3591
#  3679 3766 3854 3942 4029 4117 4204 4292 4380 4467 4555 4642 4730 4818
#  4905 4993 5080 5168 5256 5343 5431 5518 5606 5694]
# [ 2847  1847   847  -152 -1152 -2152] [  0.   78.2 156.4 234.6 312.8 391. ]
# to: [ 2847  1847   847  -152 -1152 -2152]
# (13.33, 8)
# (13.33, 8)
# Computing Dendrogram...
# Dendrogram for cmz_CO_J1_0_ saved to Dendrograms/Cropped_73.0pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram.fits

# %% [markdown]
# # x. save cube information

# %%
# Re-save the cube information, now including the dendrogram file name and the reprojected continuum

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'wb') as file:
    pickle.dump(Cube_Information, file)

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'wb') as file:
    pickle.dump(Pointing_Information, file)

print(Cube_Information)
# Out:
# {'Original_File_Name': 'tttttttttttt.fits', 'File_Descriptor': 'cmz_CO_J1_0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (180., -0.)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.15271202e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 0.125 deg>, 'original_BMIN': <Quantity 0.125 deg>, 'original_BMAJ_pc': <Quantity 1.78416283e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 1.78416283e-05 Mpc rad>, 'desired_beam_size': <Quantity 73. pc>, 'original_pixel_scale_x': <Quantity 450. arcsec / pix>, 'original_pixel_scale_y': <Quantity 450. arcsec / pix>, 'original_spatial_scale_x': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 1.78416283e-05 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 0.00027778 deg pix / arcsec>, 'original_beam_oversampling_MIN': <Quantity 0.00027778 deg pix / arcsec>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_73.0pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 368.23993289 arcsec / pix>, 'arc_per_pix_x': <Quantity 368.23993289 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 1841.19966447 arcsec>, 'beam_minor': <Quantity 1841.19966447 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale_y': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale': <Quantity 368.23993289 arcsec>, 'velocity_scale': <Quantity 5.00838299 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON'  'GLAT'  'VRAD-W2F'
# CRVAL : 200.0  -5.2  -251210.32480923
# CRPIX : 0.0  0.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.10228887024835  0.10228887024835  5008.3829852496
# NAXIS : 0  0, 'Corresponding_Continuum_Reprojected': 'gc_850micron_dust_Reproject_to_cmz_CO_J1_0_.fits', 'RMS_Noise': <Quantity 0.03010535 K>, 'Corresponding_Dendrogram': 'Cropped_73.0pc_beam_cmz_CO_J1_0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram'}

# %%
# Out:
# 4.3 pc
# 5.999999999999992e-07 MPC per pix
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# 0.2134332005353266 Unmatched Noise (K) Abs =  All
# 0.2134332005353266 Matched Noise (K) Abs =  All
# 0.010994999132779756
# 7.39599999999976e-13 <class 'float'>
# 0.253411047675004 arcsec 0.253411047675004 arcsec
# 28.327250000000895 pix2
# 5 5 2 0
# 5 5 2 0 2 2
# HCN J1-0_Abs_New_Cropped_4.3pc_beam__NGC_HCN_J1_0_70x360pc_3.3_vel_res_0.16666666666666666_beam_size_req_1_times_beam_pixels_1.0_delt_factor_5.0_SNR.fits
# done
