# %%
# %run ./"0 Imports and functions.ipynb"

# Load cube information 

File_Descriptor="NGC_253_CO_J1-0_" # This changes between files based on the line description

##################################

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'rb') as file:
    
    Cube_Information = pickle.load(file)
    
with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'rb') as file:
    
    Pointing_Information = pickle.load(file)
    
print(Cube_Information)

#Cube_Information["Beam_Position_angle"] = 0*u.deg
#Cube_Information["File_Name"] = "Cropped_4.3pc_beam_NGC_253_HCN_J1-0_71.0x360.0pc_reprojecte_3.4_vel_res_.fits"
#%matplotlib widget
# Out:
# /home/ben/miniconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# astropy 5.1.dev153+gb740594dc
# spectral_cube 0.6.1.dev22+g003ef16
# spectral_cube file path /home/ben/.local/lib/python3.8/site-packages/spectral_cube/__init__.py
# reproject 0.8
# 1.23.1 Numpy
# astrodendro_file: /home/ben/.local/lib/python3.8/site-packages/astrodendro/__init__.py
# Results will be saved to Directory ./Result Files
# Cubes will be saved and loaded with Directory ./Spectral Cubes
# Plots will be saved to Directory ./Plots
# Dendrograms will be saved to Directory ./Dendrograms
# {'Original_File_Name': 'NGC253.band3.CO_1-0.PB_edge_masked.fits', 'File_Descriptor': 'NGC_253_CO_J1-0_', 'target': 'NGC253', 'center': <SkyCoord (ICRS): (ra, dec) in deg
#     (11.88808333, -25.2882)>, 'distance': <Quantity 3.5 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 78. deg>, 'target_velocity': <Quantity 250. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'Continuum_Reproject.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.152712e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 1.85039794 arcsec>, 'original_BMIN': <Quantity 1.31851268 arcsec>, 'original_BMAJ_pc': <Quantity 3.13984384e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 2.23731545e-05 Mpc rad>, 'desired_beam_size': <Quantity 73. pc>, 'original_pixel_scale_x': <Quantity 0.25 arcsec / pix>, 'original_pixel_scale_y': <Quantity 0.25 arcsec / pix>, 'original_spatial_scale_x': <Quantity 4.24211971e-06 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 4.24211971e-06 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 7.40159178 pix>, 'original_beam_oversampling_MIN': <Quantity 5.27405071 pix>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_73.0pc_beam_NGC_253_CO_J1-0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 0.86041891 arcsec / pix>, 'arc_per_pix_x': <Quantity 0.86041891 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 4.30209453 arcsec>, 'beam_minor': <Quantity 4.30209453 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale_y': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale': <Quantity 0.86041891 arcsec>, 'velocity_scale': <Quantity 5.00003336 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---SIN'  'DEC--SIN'  'VRAD-F2F'
# CRVAL : 11.912689225821  -25.310413968009  -1000.003335654
# CRPIX : 41.0  -98.0  1.0
# PC1_1 PC1_2 PC1_3  : 0.83867056794542  0.54463903501503  0.0
# PC2_1 PC2_2 PC2_3  : -0.54463903501503  0.83867056794542  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.00023900525168314  0.00023900525168314  5000.0333565764
# NAXIS : 0  0}

# %% [markdown]
# # 2a Dendogram calculation

# %%
# Calculate the dendrogram and save it 

Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5,
                      image_args={"FIGSIZE": (26.66,8),
                                   "COLORBARSCALE":2,
                                   "SCALE":1,
                                   "XLABELS_NUM":10,
                                   
                                 
                                 
                                 }
                      )
# Out:
# The continuum has unit Jy / beam
# Change to: Jy / beam
# verify unit length is non zero, length =  9 Jy / beam
# 0.051756855960364855 K   RMS Noise for NGC_253_CO_J1-0_
# (26.66, 8)
# (26.66, 8)
# (26.66, 8)
# (13.33, 8)
# (13.33, 8)
# Computing Dendrogram...
# Dendrogram for NGC_253_CO_J1-0_ saved to Dendrograms/Cropped_73.0pc_beam_NGC_253_CO_J1-0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram.fits

# %% [markdown]
# # x. save cube information

# %%
# Re-save the cube information, now including the dendrogram file name and the reprojected continuum

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'wb') as file:
    pickle.dump(Cube_Information, file)

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'wb') as file:
    pickle.dump(Pointing_Information, file)

print(Cube_Information)
# Out:
# {'Original_File_Name': 'NGC253.band3.CO_1-0.PB_edge_masked.fits', 'File_Descriptor': 'NGC_253_CO_J1-0_', 'target': 'NGC253', 'center': <SkyCoord (ICRS): (ra, dec) in deg
#     (11.88808333, -25.2882)>, 'distance': <Quantity 3.5 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 78. deg>, 'target_velocity': <Quantity 250. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 5. km / s>, 'Corresponding_Continuum': 'Continuum_Reproject.fits', 'wavelength': <Quantity 0.00260076 m>, 'restfreq': <Quantity 1.152712e+11 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 1.85039794 arcsec>, 'original_BMIN': <Quantity 1.31851268 arcsec>, 'original_BMAJ_pc': <Quantity 3.13984384e-05 Mpc rad>, 'original_BMIN_pc': <Quantity 2.23731545e-05 Mpc rad>, 'desired_beam_size': <Quantity 73. pc>, 'original_pixel_scale_x': <Quantity 0.25 arcsec / pix>, 'original_pixel_scale_y': <Quantity 0.25 arcsec / pix>, 'original_spatial_scale_x': <Quantity 4.24211971e-06 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 4.24211971e-06 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 7.40159178 pix>, 'original_beam_oversampling_MIN': <Quantity 5.27405071 pix>, 'desired_beam_oversampling': 5, 'desired_FOV': <Quantity [ 900., 2000.] pc>, 'File_Name': 'Cropped_73.0pc_beam_NGC_253_CO_J1-0_900.0x2000.0pc_reprojected_5.0_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 0.86041891 arcsec / pix>, 'arc_per_pix_x': <Quantity 0.86041891 arcsec / pix>, 'Beam_Position_angle': <Quantity 0. deg>, 'beam_major': <Quantity 4.30209453 arcsec>, 'beam_minor': <Quantity 4.30209453 arcsec>, 'beam_area_ratio': <Quantity 28.32725 pix2 / beam>, 'spatial_scale_x': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale_y': <Quantity 1.46e-05 Mpc / pix>, 'spatial_scale': <Quantity 0.86041891 arcsec>, 'velocity_scale': <Quantity 5.00003336 km / s>, 'beam_oversampling': <Quantity 5. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---SIN'  'DEC--SIN'  'VRAD-F2F'
# CRVAL : 11.912689225821  -25.310413968009  -1000.003335654
# CRPIX : 41.0  -98.0  1.0
# PC1_1 PC1_2 PC1_3  : 0.83867056794542  0.54463903501503  0.0
# PC2_1 PC2_2 PC2_3  : -0.54463903501503  0.83867056794542  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.00023900525168314  0.00023900525168314  5000.0333565764
# NAXIS : 0  0, 'Corresponding_Continuum_Reprojected': 'Continuum_Reproject_Reproject_to_NGC_253_CO_J1-0_.fits', 'RMS_Noise': <Quantity 0.05175686 K>, 'Corresponding_Dendrogram': 'Cropped_73.0pc_beam_NGC_253_CO_J1-0_900.0x2000.0pc_reprojected_5.0_vel_res__Dendrogram'}
