# %%
# %run ./"0 Imports and functions.ipynb"

# Load cube information 

File_Descriptor="cmz_HCN_J1-0_" # This changes between files based on the line description

##################################

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'rb') as file:
    
    Cube_Information = pickle.load(file)
    
with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'rb') as file:
    
    Pointing_Information = pickle.load(file)
    
print(Cube_Information)

Cube_Information["Beam_Position_angle"]=0*u.deg
#Cube_Information["File_Name"] = "Cropped_4.3pc_beam_NGC_253_HCN_J1-0_71.0x360.0pc_reprojecte_3.4_vel_res_.fits"
#%matplotlib widget 
#%matplotlib notebook
# Out:
# /home/ben/miniconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# astropy 5.1.dev153+gb740594dc
# spectral_cube 0.6.1.dev22+g003ef16
# spectral_cube file path /home/ben/.local/lib/python3.8/site-packages/spectral_cube/__init__.py
# reproject 0.8
# 1.23.1 Numpy
# astrodendro_file: /home/ben/.local/lib/python3.8/site-packages/astrodendro/__init__.py
# Results will be saved to Directory ./Result Files
# Cubes will be saved and loaded with Directory ./Spectral Cubes
# Plots will be saved to Directory ./Plots
# Dendrograms will be saved to Directory ./Dendrograms
# {'Original_File_Name': 'CMZ_3mm_HCN.fits', 'File_Descriptor': 'cmz_HCN_J1-0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (0.50833333, -0.04616)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 3.4 km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00338245 m>, 'restfreq': <Quantity 8.86318473e+10 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 38.98800015 arcsec>, 'original_BMIN': <Quantity 38.98800015 arcsec>, 'original_BMAJ_pc': <Quantity 1.54579868e-06 Mpc rad>, 'original_BMIN_pc': <Quantity 1.54579868e-06 Mpc rad>, 'desired_beam_size': <Quantity 4.3 pc>, 'original_pixel_scale_x': <Quantity 12.00000074 arcsec / pix>, 'original_pixel_scale_y': <Quantity 12.00000074 arcsec / pix>, 'original_spatial_scale_x': <Quantity 4.75776783e-07 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 4.75776783e-07 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 3.24899981 pix>, 'original_beam_oversampling_MIN': <Quantity 3.24899981 pix>, 'desired_beam_oversampling': 10, 'desired_FOV': <Quantity [ 70., 360.] pc>, 'File_Name': 'Cropped_4.3pc_beam_cmz_HCN_J1-0_70.0x360.0pc_reprojected_3.4_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 10.84542268 arcsec / pix>, 'arc_per_pix_x': <Quantity 10.84542268 arcsec / pix>, 'beam_major': <Quantity 108.45422681 arcsec>, 'beam_minor': <Quantity 108.45422681 arcsec>, 'beam_area_ratio': <Quantity 113.309 pix2 / beam>, 'Beam_Position_angle': 0.0, 'spatial_scale_x': <Quantity 4.3e-07 Mpc / pix>, 'spatial_scale_y': <Quantity 4.3e-07 Mpc / pix>, 'spatial_scale': <Quantity 10.84542268 arcsec>, 'velocity_scale': <Quantity 3.40570043 km / s>, 'beam_oversampling': <Quantity 10. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON-SIN'  'GLAT-SIN'  'VRAD-W2F'
# CRVAL : 2.0  -0.6  -251210.32480918
# CRPIX : -77.0  -102.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.003012617411424  0.003012617411424  3405.7004299697
# NAXIS : 0  0}

# %% [markdown]
# # 2a Dendogram calculation

# %%
# Calculate the dendrogram and save it 

Dendrogram_Calculation(Cube_Information,Minimum_Pixel_Requirement=1,min_delta=5,noise_requirement=5)
# Out:
# The continuum has unit
# The continuum is unitless; unit defaults to Jy/beam
# 0.013442239548700129 K   RMS Noise for cmz_HCN_J1-0_
# Dendrogram for cmz_HCN_J1-0_ saved to Dendrograms/Cropped_4.3pc_beam_cmz_HCN_J1-0_70.0x360.0pc_reprojected_3.4_vel_res__Dendrogram.fits

# %% [markdown]
# # x. save cube information

# %%
# Re-save the cube information, now including the dendrogram file name and the reprojected continuum

import pickle 

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Cube_Information", 'wb') as file:
    pickle.dump(Cube_Information, file)

with open("Spectral Cubes/Cube Information/"+File_Descriptor+"_Pointing_Information", 'wb') as file:
    pickle.dump(Pointing_Information, file)

print(Cube_Information)
# Out:
# {'Original_File_Name': 'CMZ_3mm_HCN.fits', 'File_Descriptor': 'cmz_HCN_J1-0_', 'target': 'CMZ', 'center': <SkyCoord (Galactic): (l, b) in deg
#     (359.94423333, -0.04616)>, 'crop_center': <SkyCoord (Galactic): (l, b) in deg
#     (0.50833333, -0.04616)>, 'distance': <Quantity 0.008178 Mpc>, 'target_image_rotation': <Quantity 0. deg>, 'target_inclination': <Quantity 0. deg>, 'target_velocity': <Quantity 0. km / s>, 'vaxis': 0, 'desired_velocity_resolution': <Quantity 3.4 km / s>, 'Corresponding_Continuum': 'gc_850micron_dust.fits', 'wavelength': <Quantity 0.00338245 m>, 'restfreq': <Quantity 8.86318473e+10 Hz>, 'CUNIT': <Quantity 1. deg>, 'original_BMAJ': <Quantity 38.98800015 arcsec>, 'original_BMIN': <Quantity 38.98800015 arcsec>, 'original_BMAJ_pc': <Quantity 1.54579868e-06 Mpc rad>, 'original_BMIN_pc': <Quantity 1.54579868e-06 Mpc rad>, 'desired_beam_size': <Quantity 4.3 pc>, 'original_pixel_scale_x': <Quantity 12.00000074 arcsec / pix>, 'original_pixel_scale_y': <Quantity 12.00000074 arcsec / pix>, 'original_spatial_scale_x': <Quantity 4.75776783e-07 Mpc rad / pix>, 'original_spatial_scale_y': <Quantity 4.75776783e-07 Mpc rad / pix>, 'original_beam_oversampling_MAJ': <Quantity 3.24899981 pix>, 'original_beam_oversampling_MIN': <Quantity 3.24899981 pix>, 'desired_beam_oversampling': 10, 'desired_FOV': <Quantity [ 70., 360.] pc>, 'File_Name': 'Cropped_4.3pc_beam_cmz_HCN_J1-0_70.0x360.0pc_reprojected_3.4_vel_res_.fits', 'data_unit': Unit("K"), 'arc_per_pix_y': <Quantity 10.84542268 arcsec / pix>, 'arc_per_pix_x': <Quantity 10.84542268 arcsec / pix>, 'beam_major': <Quantity 108.45422681 arcsec>, 'beam_minor': <Quantity 108.45422681 arcsec>, 'beam_area_ratio': <Quantity 113.309 pix2 / beam>, 'Beam_Position_angle': <Quantity 0. deg>, 'spatial_scale_x': <Quantity 4.3e-07 Mpc / pix>, 'spatial_scale_y': <Quantity 4.3e-07 Mpc / pix>, 'spatial_scale': <Quantity 10.84542268 arcsec>, 'velocity_scale': <Quantity 3.40570043 km / s>, 'beam_oversampling': <Quantity 10. pix>, 'wcsu': WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'GLON-SIN'  'GLAT-SIN'  'VRAD-W2F'
# CRVAL : 2.0  -0.6  -251210.32480918
# CRPIX : -77.0  -102.0  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -0.003012617411424  0.003012617411424  3405.7004299697
# NAXIS : 0  0, 'Corresponding_Continuum_Reprojected': 'gc_850micron_dust_Reproject_to_cmz_HCN_J1-0_.fits', 'RMS_Noise': <Quantity 0.01344224 K>, 'Corresponding_Dendrogram': 'Cropped_4.3pc_beam_cmz_HCN_J1-0_70.0x360.0pc_reprojected_3.4_vel_res__Dendrogram'}

# %%
# Out:
# 4.3 pc
# 5.999999999999992e-07 MPC per pix
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# 0.2134332005353266 Unmatched Noise (K) Abs =  All
# 0.2134332005353266 Matched Noise (K) Abs =  All
# 0.010994999132779756
# 7.39599999999976e-13 <class 'float'>
# 0.253411047675004 arcsec 0.253411047675004 arcsec
# 28.327250000000895 pix2
# 5 5 2 0
# 5 5 2 0 2 2
# HCN J1-0_Abs_New_Cropped_4.3pc_beam__NGC_HCN_J1_0_70x360pc_3.3_vel_res_0.16666666666666666_beam_size_req_1_times_beam_pixels_1.0_delt_factor_5.0_SNR.fits
# done
